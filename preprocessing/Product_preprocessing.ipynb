# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df_raw_sales = pd.read_csv('../data/03 Product_Data.csv')

# %%
df_raw_sales['물품대분류'].value_counts()
# Out:
# 식기/편백       203
# 과일          139
# 냉동수산        108
# 음료          106
# 생활용품        101
# 잎/줄기채소       98
# 화장품          89
# 과자           83
# 소            74
# 섬유           73
# 빵            69
# 세제/세안        69
# 밀가공          64
# 생물수산         62
# 열매채소         59
# 육가공          58
# 건강일반         55
# 콩/화본/깨       55
# 가루           49
# 돼지           48
# 뿌리채소         47
# 과일채소         46
# 수산가공         43
# 중량(정육)       42
# 식사대용         40
# 차            39
# 양념채소         39
# 유제품          37
# 떡            37
# 건어물          36
# 버섯           34
# 소스/기타양념      32
# 말린나물/건재      32
# 닭/오리         31
# 장            30
# 해조           28
# 밑반찬          27
# 견과           25
# 즉석조리         21
# 김치           20
# 알            18
# 기름/식초        18
# 홍삼/녹용        16
# 쌈채소류         15
# 멥쌀           15
# 절임/장아찌       14
# 잼/병조림/기타     13
# 어묵/묵         13
# 두부/유부        13
# 소금           11
# 유색미/발아미      10
# 보리/혼합곡       10
# 꿀            10
# 전통주           8
# 과실주           6
# ...

# %%
df_raw_sales.loc[df_raw_sales['물품대분류'] == '찹쌀', '물품대분류'] ='쌀/잡곡/견과'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '보리/혼합곡', '물품대분류'] ='쌀/잡곡/견과'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '유색미/발아미', '물품대분류'] ='쌀/잡곡/견과'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '멥쌀', '물품대분류'] ='쌀/잡곡/견과'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '콩/화본/깨', '물품대분류'] ='쌀/잡곡/견과'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '견과', '물품대분류'] ='쌀/잡곡/견과'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '열매채소', '물품대분류'] ='채소'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '잎/줄기채소', '물품대분류'] ='채소'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '뿌리채소', '물품대분류'] ='채소'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '김장채소', '물품대분류'] ='채소'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '콩나물', '물품대분류'] ='채소'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '쌈채소류', '물품대분류'] ='채소'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '양념채소', '물품대분류'] ='채소'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '손질한채소', '물품대분류'] ='채소'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '버섯', '물품대분류'] ='채소'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '말린나물/건재', '물품대분류'] ='채소'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '과일채소', '물품대분류'] ='과일'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '과실주', '물품대분류'] ='주류'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '전통주', '물품대분류'] ='주류'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '냉동수산', '물품대분류'] ='수산/건어물'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '생물수산', '물품대분류'] ='수산/건어물'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '수산가공', '물품대분류'] ='수산/건어물'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '건어물', '물품대분류'] ='수산/건어물'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '해조', '물품대분류'] ='수산/건어물'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '차', '물품대분류'] ='음료'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '섬유', '물품대분류'] ='생활용품'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '세제/세안', '물품대분류'] ='생활용품'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '과자', '물품대분류'] ='간식/떡'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '떡', '물품대분류'] ='간식/떡'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '돼지', '물품대분류'] ='정육/계란'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '소', '물품대분류'] ='정육/계란'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '중량(정육)', '물품대분류'] ='정육/계란' 
df_raw_sales.loc[df_raw_sales['물품대분류'] == '알', '물품대분류'] ='정육/계란'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '닭/오리', '물품대분류'] ='정육/계란'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '육가공', '물품대분류'] ='정육/계란'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '밀가공', '물품대분류'] ='냉장/냉동/간편식'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '식사대용', '물품대분류'] ='냉장/냉동/간편식'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '즉석조리', '물품대분류'] ='냉장/냉동/간편식'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '어묵/묵', '물품대분류'] ='냉장/냉동/간편식'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '두부/유부', '물품대분류'] ='냉장/냉동/간편식'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '건강일반', '물품대분류'] ='건강식품'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '홍삼/녹용', '물품대분류'] ='건강식품'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '가루', '물품대분류'] ='양념/장류/오일'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '기름/식초', '물품대분류'] ='양념/장류/오일'  
df_raw_sales.loc[df_raw_sales['물품대분류'] == '소스/기타양념', '물품대분류'] ='양념/장류/오일'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '장', '물품대분류'] ='양념/장류/오일'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '소금', '물품대분류'] ='양념/장류/오일'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '꿀', '물품대분류'] ='양념/장류/오일'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '절임/장아찌', '물품대분류'] ='김치/반찬'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '김치', '물품대분류'] ='김치/반찬'
df_raw_sales.loc[df_raw_sales['물품대분류'] == '밑반찬', '물품대분류'] ='김치/반찬'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '잼/병조림/기타', '물품대분류'] ='잼/통조림'

df_raw_sales.loc[df_raw_sales['물품대분류'] == '식기/편백', '물품대분류'] ='주방용품'

# %%
df_raw_sales.to_csv('../data/Product_전처리.csv', encoding="utf-8-sig")
